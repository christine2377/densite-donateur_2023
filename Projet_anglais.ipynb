# %% [markdown]
# <a href="https://colab.research.google.com/github/christine2377/densite-donateur_2023/blob/main/Projet_anglais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import fonctions as fct
from statsmodels.graphics.tsaplots import plot_acf

# %%
AC=pd.read_csv("/content/tables_cours/AC.PA.csv",index_col = 0, parse_dates=True)
AC['log_close'] = np.log(AC.Close)
AC
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2021-01-04  30.059999  30.660000  29.010000  29.010000  28.709013   729748
# 2021-01-05  28.790001  29.490000  28.600000  29.070000  28.768389   522884
# 2021-01-06  29.490000  30.600000  28.900000  30.070000  29.758015  1082739
# 2021-01-07  30.280001  30.280001  29.170000  29.700001  29.391853   620092
# 2021-01-08  30.030001  30.600000  29.799999  30.020000  29.708534  1115847
# ...               ...        ...        ...        ...        ...      ...
# 2023-12-21  34.419998  34.759998  34.330002  34.680000  34.680000   544461
# 2023-12-22  34.590000  34.830002  34.549999  34.740002  34.740002   395843
# 2023-12-27  34.660000  34.820000  34.599998  34.689999  34.689999   330692
# 2023-12-28  34.689999  34.849998  34.520000  34.560001  34.560001   304280
# 2023-12-29  34.580002  34.740002  34.529999  34.599998  34.599998   178636
#
#             log_close
# Date
# 2021-01-04   3.367641
# ...

# %%
fig,ax = plt.subplots()
ln1 = ax.plot(AC.Close,c='r', label = "Cours de AC")
ax2 = ax.twinx()
ln2 = ax2.plot(AC.log_close, c='b', label= "Cours de AC en log")
lns= ln1+ln2
labels = [l.get_label() for l in lns]
ax.legend(lns,labels)

# %%
plot_acf(AC.Close.value)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-52fd5a9529e9> in <cell line: 1>()
# ----> 1 plot_acf(AC.Close.value)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value'

# %%
BNP=pd.read_csv("/content/tables_cours/BNP.PA.csv",index_col = 0, parse_dates=True)
BNP['log_close'] = np.log(BNP.Close)
BNP
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2021-01-04  43.860001  43.915001  42.639999  43.009998  35.713257  3025708
# 2021-01-05  42.720001  43.474998  42.314999  42.919998  35.638527  2852830
# 2021-01-06  43.970001  46.009998  43.779999  45.290001  37.606453  5959237
# 2021-01-07  45.974998  46.605000  45.240002  46.310001  38.453403  4336483
# 2021-01-08  46.474998  46.660000  45.169998  45.285000  37.602299  3864732
# ...               ...        ...        ...        ...        ...      ...
# 2023-12-21  62.599998  62.880001  62.090000  62.880001  62.880001  1458810
# 2023-12-22  63.000000  63.369999  62.900002  63.009998  63.009998  1279974
# 2023-12-27  63.099998  63.540001  62.770000  62.990002  62.990002  1184940
# 2023-12-28  63.119999  63.240002  62.340000  62.450001  62.450001   856379
# 2023-12-29  62.419998  62.849998  62.419998  62.590000  62.590000   764511
#
#             log_close
# Date
# 2021-01-04   3.761433
# ...

# %%
fig,ax = plt.subplots()
ln1 = ax.plot(BNP.Close,c='r', label = "Cours de BNP")
ax2 = ax.twinx()
ln2 = ax2.plot(BNP.log_close, c='b', label= "Cours de BNP en log")
lns= ln1+ln2
labels = [l.get_label() for l in lns]
ax.legend(lns,labels)

# %%
CA=pd.read_csv("/content/tables_cours/CA.PA.csv",index_col = 0, parse_dates=True)
CA['log_close'] = np.log(CA.Close)
CA
# Out:
#                  Open    High        Low      Close  Adj Close   Volume  \
# Date
# 2021-01-04  14.150000  14.525  14.115000  14.490000  13.265677  5056879
# 2021-01-05  14.515000  15.150  14.285000  15.010000  13.741741  7508843
# 2021-01-06  15.050000  15.615  15.005000  15.340000  14.043858  6758871
# 2021-01-07  15.410000  15.470  15.300000  15.420000  14.117098  3484432
# 2021-01-08  15.435000  15.445  15.120000  15.240000  13.952306  3748054
# ...               ...     ...        ...        ...        ...      ...
# 2023-12-21  16.639999  16.650  16.475000  16.555000  16.555000   807486
# 2023-12-22  16.530001  16.635  16.510000  16.620001  16.620001   719610
# 2023-12-27  16.570000  16.660  16.490000  16.620001  16.620001   724465
# 2023-12-28  16.594999  16.650  16.549999  16.570000  16.570000   991406
# 2023-12-29  16.559999  16.635  16.510000  16.565001  16.565001   682443
#
#             log_close
# Date
# 2021-01-04   2.673459
# 2021-01-05   2.708717
# ...

# %%
fig,ax = plt.subplots()
ln1 = ax.plot(CA.Close,c='r', label = "Cours de CA")
ax2 = ax.twinx()
ln2 = ax2.plot(CA.log_close, c='b', label= "Cours de CA en log")
lns= ln1+ln2
labels = [l.get_label() for l in lns]
ax.legend(lns,labels)
